# %%
import pandas as pd

df = pd.read_csv('eb.csv')
print(df)
print(df.columns)
# Out:
#        Consumer_ID Meter_Number    Customer_Name   Bill_Date  Units_Consumed  \
# 0             1001    MTR000001       Customer_1  2024-05-10          279.92
# 1             1002    MTR000002       Customer_2  2024-11-10          302.56
# 2             1003    MTR000003       Customer_3  2022-05-02          316.74
# 3             1004    MTR000004       Customer_4  2023-04-12          295.73
# 4             1005    MTR000005       Customer_5  2022-11-27          248.61
# ...            ...          ...              ...         ...             ...
# 99995       100996    MTR099996   Customer_99996  2024-06-08          255.85
# 99996       100997    MTR099997   Customer_99997  2024-02-04          250.67
# 99997       100998    MTR099998   Customer_99998  2023-03-15          240.94
# 99998       100999    MTR099999   Customer_99999  2022-05-14          275.89
# 99999       101000    MTR100000  Customer_100000  2024-05-31          259.85
#
# ...

# %%
df['Units_Consumed'].hist(bins=30, edgecolor='black')
# Out:
# <Axes: >
